# %%
import pandas as pd

# CSV File Name
CSV_FILE = "thai_air_data.csv"

df = pd.read_csv(CSV_FILE)

print(df)
print(df['JSON'])
# Out:
#               Timestamp                 City  AQI  PM2.5  \
# 0   2025-02-19 18:11:33         Samut Prakan  110  110.0
# 1   2025-02-19 18:11:33    Nakhon Ratchasima  100  100.0
# 2   2025-02-19 18:11:34                Surin    -    NaN
# 3   2025-02-19 18:11:34         Sakon Nakhon   63   63.0
# 4   2025-02-19 18:11:35     Mueang Khon Kaen   79   79.0
# 5   2025-02-19 18:11:35            Nong Khai   75   75.0
# 6   2025-02-19 18:11:36         Kanchanaburi  117  117.0
# 7   2025-02-19 18:11:36          Suphan Buri   52   52.0
# 8   2025-02-19 18:11:37          Uthai Thani   13   13.0
# 9   2025-02-19 18:11:38         Nakhon Sawan   94   94.0
# 10  2025-02-19 18:11:38          Phitsanulok  134  134.0
# 11  2025-02-19 18:11:39       Kamphaeng Phet  261  261.0
# 12  2025-02-19 18:11:40              Lamphun   90   90.0
# 13  2025-02-19 18:11:41              Lampang  104  104.0
# 14  2025-02-19 18:11:41               Phayao  107  107.0
# ...

# %%
df
# Out:
#               Timestamp                 City  AQI  PM2.5  \
# 0   2025-02-19 18:11:33         Samut Prakan  110  110.0
# 1   2025-02-19 18:11:33    Nakhon Ratchasima  100  100.0
# 2   2025-02-19 18:11:34                Surin    -    NaN
# 3   2025-02-19 18:11:34         Sakon Nakhon   63   63.0
# 4   2025-02-19 18:11:35     Mueang Khon Kaen   79   79.0
# 5   2025-02-19 18:11:35            Nong Khai   75   75.0
# 6   2025-02-19 18:11:36         Kanchanaburi  117  117.0
# 7   2025-02-19 18:11:36          Suphan Buri   52   52.0
# 8   2025-02-19 18:11:37          Uthai Thani   13   13.0
# 9   2025-02-19 18:11:38         Nakhon Sawan   94   94.0
# 10  2025-02-19 18:11:38          Phitsanulok  134  134.0
# 11  2025-02-19 18:11:39       Kamphaeng Phet  261  261.0
# 12  2025-02-19 18:11:40              Lamphun   90   90.0
# 13  2025-02-19 18:11:41              Lampang  104  104.0
# 14  2025-02-19 18:11:41               Phayao  107  107.0
# ...

# %%
df['JSON']
# Out:
# 0     {'aqi': 110, 'idx': 1842, 'attributions': [{'u...
# 1     {'aqi': 100, 'idx': 1854, 'attributions': [{'u...
# 2     {'aqi': '-', 'idx': 12801, 'attributions': [{'...
# 3     {'aqi': 63, 'idx': 13631, 'attributions': [{'u...
# 4     {'aqi': 79, 'idx': 3688, 'attributions': [{'ur...
# 5     {'aqi': 75, 'idx': 12795, 'attributions': [{'u...
# 6     {'aqi': 117, 'idx': 10481, 'attributions': [{'...
# 7     {'aqi': 52, 'idx': 13633, 'attributions': [{'u...
# 8     {'aqi': 13, 'idx': 13626, 'attributions': [{'u...
# 9     {'aqi': 94, 'idx': 1825, 'attributions': [{'ur...
# 10    {'aqi': 134, 'idx': 13635, 'attributions': [{'...
# 11    {'aqi': 261, 'idx': 11399, 'attributions': [{'...
# 12    {'aqi': 90, 'idx': 1868, 'attributions': [{'ur...
# 13    {'aqi': 104, 'idx': 1823, 'attributions': [{'u...
# 14    {'aqi': 107, 'idx': 1831, 'attributions': [{'u...
# 15    {'aqi': 120, 'idx': 5773, 'attributions': [{'u...
# 16    {'aqi': 81, 'idx': 13632, 'attributions': [{'u...
# ...
